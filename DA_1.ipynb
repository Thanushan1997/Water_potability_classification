# %%
  import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import scipy.stats as stats

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("airline_passenger_satisfaction.csv")

# %%
df.shape
# Out:
# (129880, 24)

# %%
df.head()
# Out:
#    Unnamed: 0  Gender      customer_type  age   type_of_travel customer_class  \
# 0           0    Male     Loyal Customer   13  Personal Travel       Eco Plus
# 1           1    Male  disloyal Customer   25  Business travel       Business
# 2           2  Female     Loyal Customer   26  Business travel       Business
# 3           3  Female     Loyal Customer   25  Business travel       Business
# 4           4    Male     Loyal Customer   61  Business travel       Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# Gender                                object
# customer_type                         object
# age                                    int64
# type_of_travel                        object
# customer_class                        object
# flight_distance                        int64
# inflight_wifi_service                  int64
# departure_arrival_time_convenient      int64
# ease_of_online_booking                 int64
# gate_location                          int64
# food_and_drink                         int64
# online_boarding                        int64
# seat_comfort                           int64
# inflight_entertainment                 int64
# onboard_service                        int64
# leg_room_service                       int64
# baggage_handling                       int64
# checkin_service                        int64
# inflight_service                       int64
# cleanliness                            int64
# ...

# %%
data = df.drop('Unnamed: 0', axis=1)

# %%
# split into train test sets
train, test = train_test_split(data,test_size=0.2,random_state= 20)

# %%
train.shape
# Out:
# (103904, 23)

# %%
train.head()
# Out:
#         Gender      customer_type  age   type_of_travel customer_class  \
# 62212   Female     Loyal Customer   39  Business travel       Business
# 69250     Male     Loyal Customer   49  Business travel       Business
# 21132   Female     Loyal Customer   64  Personal Travel            Eco
# 120003  Female     Loyal Customer   48  Business travel       Business
# 68495     Male  disloyal Customer   33  Business travel            Eco
#
#         flight_distance  inflight_wifi_service  \
# 62212              3624                      1
# 69250              3536                      2
# 21132               308                      2
# 120003             1428                      2
# 68495               554                      1
#
#         departure_arrival_time_convenient  ease_of_online_booking  \
# 62212                                   3                       1
# 69250                                   2                       2
# ...

# %%
train.isnull().sum()
# Out:
# Gender                                 0
# customer_type                          0
# age                                    0
# type_of_travel                         0
# customer_class                         0
# flight_distance                        0
# inflight_wifi_service                  0
# departure_arrival_time_convenient      0
# ease_of_online_booking                 0
# gate_location                          0
# food_and_drink                         0
# online_boarding                        0
# seat_comfort                           0
# inflight_entertainment                 0
# onboard_service                        0
# leg_room_service                       0
# baggage_handling                       0
# checkin_service                        0
# inflight_service                       0
# cleanliness                            0
# departure_delay_in_minutes             0
# arrival_delay_in_minutes             318
# satisfaction                           0
# ...

# %%
cols =['inflight_wifi_service','departure_arrival_time_convenient','ease_of_online_booking','gate_location','food_and_drink','online_boarding','seat_comfort','inflight_entertainment','onboard_service','leg_room_service','baggage_handling','checkin_service','inflight_service','cleanliness']
for col in cols:
    train[col] = train[col].astype('category')
# Out:
# C:\Users\thanu\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
train.dtypes
# Out:
# Gender                                 object
# customer_type                          object
# age                                     int64
# type_of_travel                         object
# customer_class                         object
# flight_distance                         int64
# inflight_wifi_service                category
# departure_arrival_time_convenient    category
# ease_of_online_booking               category
# gate_location                        category
# food_and_drink                       category
# online_boarding                      category
# seat_comfort                         category
# inflight_entertainment               category
# onboard_service                      category
# leg_room_service                     category
# baggage_handling                     category
# checkin_service                      category
# inflight_service                     category
# cleanliness                          category
# ...

# %%
numerical_features = train.select_dtypes(include=np.number).columns.to_list()
numerical_features
# Out:
# ['age',
#  'flight_distance',
#  'departure_delay_in_minutes',
#  'arrival_delay_in_minutes']

# %%
categorical_features = train.select_dtypes(exclude=np.number).columns.to_list()
categorical_features
# Out:
# ['Gender',
#  'customer_type',
#  'type_of_travel',
#  'customer_class',
#  'inflight_wifi_service',
#  'departure_arrival_time_convenient',
#  'ease_of_online_booking',
#  'gate_location',
#  'food_and_drink',
#  'online_boarding',
#  'seat_comfort',
#  'inflight_entertainment',
#  'onboard_service',
#  'leg_room_service',
#  'baggage_handling',
#  'checkin_service',
#  'inflight_service',
#  'cleanliness',
#  'satisfaction']

# %%
import seaborn as sns

# %%
corr = train[numerical_features].corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)

# %%
plt.hist(train['arrival_delay_in_minutes'], bins=[0,20,40,60,80,100,120,140,160,180,200,220,240,260,280,300,320], align='right', color='lightblue', edgecolor='black')
plt.xlabel('arrival_delay_in_minutes')
plt.ylabel('no_of_delays')
plt.title('Arrival_delay_Distribution')
# Out:
# Text(0.5, 1.0, 'Arrival_delay_Distribution')

# %%
train['arrival_delay_in_minutes'] = train['arrival_delay_in_minutes'].fillna(train['arrival_delay_in_minutes'].median())
# Out:
# C:\Users\thanu\anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
train.isnull().sum()
# Out:
# Gender                               0
# customer_type                        0
# age                                  0
# type_of_travel                       0
# customer_class                       0
# flight_distance                      0
# inflight_wifi_service                0
# departure_arrival_time_convenient    0
# ease_of_online_booking               0
# gate_location                        0
# food_and_drink                       0
# online_boarding                      0
# seat_comfort                         0
# inflight_entertainment               0
# onboard_service                      0
# leg_room_service                     0
# baggage_handling                     0
# checkin_service                      0
# inflight_service                     0
# cleanliness                          0
# departure_delay_in_minutes           0
# arrival_delay_in_minutes             0
# satisfaction                         0
# dtype: int64

# %%
train.head(30)
# Out:
#         Gender      customer_type  age   type_of_travel customer_class  \
# 62212   Female     Loyal Customer   39  Business travel       Business
# 69250     Male     Loyal Customer   49  Business travel       Business
# 21132   Female     Loyal Customer   64  Personal Travel            Eco
# 120003  Female     Loyal Customer   48  Business travel       Business
# 68495     Male  disloyal Customer   33  Business travel            Eco
# 48618   Female     Loyal Customer   15  Personal Travel       Business
# 72966   Female     Loyal Customer   31  Business travel       Business
# 61907     Male  disloyal Customer   37  Business travel            Eco
# 26094   Female     Loyal Customer   61  Business travel       Business
# 21930     Male     Loyal Customer   15  Personal Travel            Eco
# 75742     Male     Loyal Customer   59  Business travel       Business
# 60948   Female     Loyal Customer   62  Personal Travel            Eco
# ...

# %%
train.arrival_delay_in_minutes = train.arrival_delay_in_minutes.astype('float')
train.arrival_delay_in_minutes = train.arrival_delay_in_minutes.astype('Int64')
# Out:
# C:\Users\thanu\anaconda3\envs\py37\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
train.head()
# Out:
#         Gender      customer_type  age   type_of_travel customer_class  \
# 62212   Female     Loyal Customer   39  Business travel       Business
# 69250     Male     Loyal Customer   49  Business travel       Business
# 21132   Female     Loyal Customer   64  Personal Travel            Eco
# 120003  Female     Loyal Customer   48  Business travel       Business
# 68495     Male  disloyal Customer   33  Business travel            Eco
#
#         flight_distance inflight_wifi_service  \
# 62212              3624                     1
# 69250              3536                     2
# 21132               308                     2
# 120003             1428                     2
# 68495               554                     1
#
#        departure_arrival_time_convenient ease_of_online_booking gate_location  \
# 62212                                  3                      1             1
# 69250                                  2                      2             2
# ...

# %%
train.dtypes
# Out:
# Gender                                 object
# customer_type                          object
# age                                     int64
# type_of_travel                         object
# customer_class                         object
# flight_distance                         int64
# inflight_wifi_service                category
# departure_arrival_time_convenient    category
# ease_of_online_booking               category
# gate_location                        category
# food_and_drink                       category
# online_boarding                      category
# seat_comfort                         category
# inflight_entertainment               category
# onboard_service                      category
# leg_room_service                     category
# baggage_handling                     category
# checkin_service                      category
# inflight_service                     category
# cleanliness                          category
# ...

# %%
train.head(10)
# Out:
#         Gender      customer_type  age   type_of_travel customer_class  \
# 62212   Female     Loyal Customer   39  Business travel       Business
# 69250     Male     Loyal Customer   49  Business travel       Business
# 21132   Female     Loyal Customer   64  Personal Travel            Eco
# 120003  Female     Loyal Customer   48  Business travel       Business
# 68495     Male  disloyal Customer   33  Business travel            Eco
# 48618   Female     Loyal Customer   15  Personal Travel       Business
# 72966   Female     Loyal Customer   31  Business travel       Business
# 61907     Male  disloyal Customer   37  Business travel            Eco
# 26094   Female     Loyal Customer   61  Business travel       Business
# 21930     Male     Loyal Customer   15  Personal Travel            Eco
#
#         flight_distance inflight_wifi_service  \
# 62212              3624                     1
# 69250              3536                     2
# ...

# %%
for i,col in enumerate(numerical_features):
    plt.hist(train[col],bins=30)
    plt.title(f'{col}')
    plt.figure(figsize=(15,4))
    fig = plt.figure(figsize=(15,15))
    fig.savefig('uninumerical.jpg', bbox_inches='tight', dpi=150)
    plt.show()

# %%
corr = train[numerical_features].corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
fig = plt.figure(figsize=(15,15))
fig.savefig('numericalcorr.jpg', bbox_inches='tight', dpi=150)
plt.show()

# %%
for i,col in enumerate(categorical_features):
    sns.countplot(data=train, x = col)
    plt.title(f'{col}')
    plt.figure(figsize=(10,10))
    plt.show()
    print("{}: \n {}".format(col,train[col].value_counts()))
# Out:
# Gender:
#  Female    52678
# Male      51226
# Name: Gender, dtype: int64
# customer_type:
#  Loyal Customer       84960
# disloyal Customer    18944
# Name: customer_type, dtype: int64
# type_of_travel:
#  Business travel    71746
# Personal Travel    32158
# Name: type_of_travel, dtype: int64
# customer_class:
#  Business    49638
# Eco         46693
# Eco Plus     7573
# Name: customer_class, dtype: int64
# inflight_wifi_service:
#  2    25824
# 3    25710
# 4    19846
# 1    17884
# 5    11528
# 0     3112
# Name: inflight_wifi_service, dtype: int64
# departure_arrival_time_convenient:
#  4    25426
# 5    22539
# 3    17968
# 2    17139
# 1    15567
# 0     5265
# Name: departure_arrival_time_convenient, dtype: int64
# ease_of_online_booking:
#  3    24332
# 2    23897
# 4    19564
# 1    17582
# 5    14007
# 0     4522
# Name: ease_of_online_booking, dtype: int64
# gate_location:
#  3    28605
# 4    24377
# 2    19330
# 1    17649
# 5    13942
# 0        1
# ...

# %%
for i,col in enumerate(numerical_features):
    sns.boxplot(x='satisfaction',y = train[col],data=train)
    plt.title(f'BIvariate analysis of {col} vs satisfaction')
    plt.figure(figsize=(15,15))

# %%
sns.boxplot(x='satisfaction',y = 'flight_distance',data=train)
fig = plt.figure(figsize=(15,15))
fig.savefig('flightdistance.jpg', bbox_inches='tight', dpi=150)
plt.show()

# %%
sns.boxplot(x='food_and_drink',y = 'age',data=train)
fig = plt.figure(figsize=(15,15))
fig.savefig('flightdistance.jpg', bbox_inches='tight', dpi=150)
plt.show()

# %%
sns.boxplot(x='food_and_drink',y = 'flight_distance',data=train)
fig = plt.figure(figsize=(15,15))
plt.show()

# %%
sns.boxplot(x='inflight_wifi_service',y = 'age',data=train)
fig = plt.figure(figsize=(15,15))
plt.show()

# %%
sns.boxplot(x='type_of_travel',y = 'age',data=train)
fig = plt.figure(figsize=(15,15))
plt.show()

# %%
sns.boxplot(x='customer_class',y = 'age',data=train)
fig = plt.figure(figsize=(15,15))
plt.show()

# %%
with sns.axes_style('white'):
    g = sns.catplot(x='age', data=train, aspect=3.0, kind='count', hue='satisfaction')
    plt.title('BIvariate analysis of age vs satisfaction')
    fig = plt.figure(figsize=(15,15))
    fig.savefig('agevssatisfaction.jpg', bbox_inches='tight', dpi=150)
    plt.show()

# %%
for i,col in enumerate(categorical_features[0:-1]): 
    with sns.axes_style(style='ticks'):
        sns.catplot(x="satisfaction", col=col, col_wrap=6, data=train, kind="count", height=2.5, aspect=1.0) 
        plt.figure(figsize=(20,20))
        plt.show()

# %%
train_cat = train.loc[:,categorical_features]
train_cat
# Out:
#         Gender      customer_type   type_of_travel customer_class  \
# 62212   Female     Loyal Customer  Business travel       Business
# 69250     Male     Loyal Customer  Business travel       Business
# 21132   Female     Loyal Customer  Personal Travel            Eco
# 120003  Female     Loyal Customer  Business travel       Business
# 68495     Male  disloyal Customer  Business travel            Eco
# ...        ...                ...              ...            ...
# 88988   Female     Loyal Customer  Business travel       Business
# 23775   Female     Loyal Customer  Personal Travel            Eco
# 37135   Female     Loyal Customer  Business travel       Business
# 92634     Male     Loyal Customer  Business travel       Business
# 114019  Female  disloyal Customer  Business travel       Business
#
#        inflight_wifi_service departure_arrival_time_convenient  \
# 62212                      1                                 3
# ...

# %%
def cramers_v(x, y):
    x = np.array(x)
    y = np.array(y)
    confusion_matrix = pd.crosstab(x, y)
    chi2 = stats.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))


cramersv = pd.DataFrame(index=train_cat.columns,columns=train_cat.columns)
columns = train_cat.columns

for i in range(0,len(columns)):
    for j in range(0,len(columns)):
        #print(data[columns[i]].tolist())
        u = cramers_v(data[columns[i]].tolist(),data[columns[j]].tolist())
        cramersv.loc[columns[i],columns[j]] = u
        
cramersv.fillna(value=np.nan,inplace=True)

# %%
fig = plt.figure(figsize=(15,15))
sns.heatmap(cramersv, annot=True)
fig.savefig('catcorr.jpg', bbox_inches='tight', dpi=150)
plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize=(30,15))
for variable, subplot in zip(categorical_features[0:4], ax.flatten()):
    sns.countplot(x=train[variable],hue=train['satisfaction'], ax=subplot)

# %%
fig, ax = plt.subplots(2,2, figsize=(30,15))
for variable, subplot in zip(categorical_features[4:8], ax.flatten()):
    sns.countplot(x=train[variable],hue=train['satisfaction'], ax=subplot)

# %%
fig, ax = plt.subplots(2,2, figsize=(30,15))
for variable, subplot in zip(categorical_features[8:12], ax.flatten()):
    sns.countplot(x=train[variable],hue=train['satisfaction'], ax=subplot)

# %%
fig, ax = plt.subplots(2,2, figsize=(30,15))
for variable, subplot in zip(categorical_features[12:16], ax.flatten()):
    sns.countplot(x=train[variable],hue=train['satisfaction'], ax=subplot)

# %%
fig, ax = plt.subplots(1,2, figsize=(30,15))
for variable, subplot in zip(categorical_features[16:18], ax.flatten()):
    sns.countplot(x=train[variable],hue=train['satisfaction'], ax=subplot)

# %%
categorical_features
# Out:
# ['Gender',
#  'customer_type',
#  'type_of_travel',
#  'customer_class',
#  'inflight_wifi_service',
#  'departure_arrival_time_convenient',
#  'ease_of_online_booking',
#  'gate_location',
#  'food_and_drink',
#  'online_boarding',
#  'seat_comfort',
#  'inflight_entertainment',
#  'onboard_service',
#  'leg_room_service',
#  'baggage_handling',
#  'checkin_service',
#  'inflight_service',
#  'cleanliness',
#  'satisfaction']

# %%
train['customer_class'].unique()
# Out:
# array(['Business', 'Eco', 'Eco Plus'], dtype=object)

# %%
Business = train['customer_class'] == 'Business'
Eco = train['customer_class'] == 'Eco'
Eco_Plus = train['customer_class'] == 'Eco Plus'
cat0 = train['type_of_travel'] [Business].dropna()
cat1 = train['type_of_travel'] [Eco].dropna()
cat2 = train['type_of_travel'] [Eco_Plus].dropna()
freq1 = cat0.value_counts()
freq2 = cat1.value_counts()
freq3 = cat2.value_counts()
plotdata = pd.DataFrame({'Business':freq1 , 'Eco':freq2 , 'Eco Plus':freq3})
plotdata2 = plotdata.div(plotdata.sum(axis=1),axis=0)*100
plotdata2.plot(kind='bar',stacked =True)
plt.legend(train['customer_class'].unique(),bbox_to_anchor = (1.05,1))
plt.xlabel('Type of travel')
plt.ylabel('cumulative percentage')
# Out:
# Text(0, 0.5, 'cumulative percentage')

# %%
Business = train['customer_class'] == 'Business'
Eco = train['customer_class'] == 'Eco'
Eco_Plus = train['customer_class'] == 'Eco Plus'
cat0 = train['satisfaction'] [Business].dropna()
cat1 = train['satisfaction'] [Eco].dropna()
cat2 = train['satisfaction'] [Eco_Plus].dropna()
freq1 = cat0.value_counts()
freq2 = cat1.value_counts()
freq3 = cat2.value_counts()
plotdata = pd.DataFrame({'Business':freq1 , 'Eco':freq2 , 'Eco Plus':freq3})
plotdata2 = plotdata.div(plotdata.sum(axis=1),axis=0)*100
plotdata2.plot(kind='bar',stacked =True)
plt.legend(train['customer_class'].unique(),bbox_to_anchor = (1.05,1))
plt.xlabel('satisfaction')
plt.ylabel('cumulative percentage')
# Out:
# Text(0, 0.5, 'cumulative percentage')

# %%
Business = train['customer_class'] == 'Business'
Eco = train['customer_class'] == 'Eco'
Eco_Plus = train['customer_class'] == 'Eco Plus'
cat0 = train['customer_type'] [Business].dropna()
cat1 = train['customer_type'] [Eco].dropna()
cat2 = train['customer_type'] [Eco_Plus].dropna()
freq1 = cat0.value_counts()
freq2 = cat1.value_counts()
freq3 = cat2.value_counts()
plotdata = pd.DataFrame({'Business':freq1 , 'Eco':freq2 , 'Eco Plus':freq3})
plotdata2 = plotdata.div(plotdata.sum(axis=1),axis=0)*100
plotdata2.plot(kind='bar',stacked =True)
plt.legend(train['customer_class'].unique(),bbox_to_anchor = (1.05,1))
plt.xlabel('customer_type')
plt.ylabel('cumulative percentage')
# Out:
# Text(0, 0.5, 'cumulative percentage')

# %%
sns.catplot(x="cleanliness", hue="inflight_entertainment", kind="count",palette="pastel",data=train)

# %%
sns.catplot(x="cleanliness", hue="food_and_drink", kind="count",palette="pastel",data=train)

# %%
sns.catplot(x="onboard_service", hue="inflight_service", kind="count",palette="pastel",data=train)

# %%
sns.catplot(x="ease_of_online_booking", hue="inflight_wifi_service", kind="count",palette="pastel",data=train)

# %%
satisfactionvalues = train['satisfaction'].value_counts()
satisfactionvalues
# Out:
# neutral or dissatisfied    58723
# satisfied                  45181
# Name: satisfaction, dtype: int64

# %%
satisfied = train['satisfaction'] == 'satisfied'
notsatisfied_neutral = train['satisfaction'] == 'neutral or dissatisfied'
cat0 = train['ease_of_online_booking'] [satisfied].dropna()
cat1 = train['ease_of_online_booking'] [notsatisfied_neutral].dropna()
freq1 = cat0.value_counts()
freq2 = cat1.value_counts()
plotdata = pd.DataFrame({'satisfied':freq1 , 'neutral or dissatisfied':freq2 })
plotdata2 = plotdata.div(plotdata.sum(axis=1),axis=0)*100
plotdata2.plot(kind='bar',stacked =True)
plt.legend(train['satisfaction'].unique(),bbox_to_anchor = (1.05,1))
plt.xlabel('ease_of_online_booking')
plt.ylabel('cumulative percentage')
# Out:
# Text(0, 0.5, 'cumulative percentage')

# %%
satisfied = train['satisfaction'] == 'satisfied'
notsatisfied_neutral = train['satisfaction'] == 'neutral or dissatisfied'
cat0 = train['customer_type'] [satisfied].dropna()
cat1 = train['customer_type'] [notsatisfied_neutral].dropna()
freq1 = cat0.value_counts()
freq2 = cat1.value_counts()
plotdata = pd.DataFrame({'satisfied':freq1 , 'neutral or dissatisfied':freq2 })
plotdata2 = plotdata.div(plotdata.sum(axis=1),axis=0)*100
plotdata2.plot(kind='bar',stacked =True)
plt.legend(train['satisfaction'].unique(),bbox_to_anchor = (1.05,1))
plt.xlabel('customer_type')
plt.ylabel('cumulative percentage')
fig = plt.figure(figsize=(15,15))
fig.savefig('satisfactionvscustomertype.jpg', bbox_inches='tight', dpi=150)
plt.show()

# %%
satisfied = train['customer_type'] == 'Loyal Customer'
notsatisfied_neutral = train['customer_type'] == 'disloyal Customer'
cat0 = train['customer_class'] [satisfied].dropna()
cat1 = train['customer_class'] [notsatisfied_neutral].dropna()
freq1 = cat0.value_counts()
freq2 = cat1.value_counts()
plotdata = pd.DataFrame({'Loyal customer':freq1 , 'Disloyal Customer':freq2 })
plotdata2 = plotdata.div(plotdata.sum(axis=1),axis=0)*100
plotdata2.plot(kind='bar',stacked =True)
plt.legend(train['customer_type'].unique(),bbox_to_anchor = (1.05,1))
plt.xlabel('customer class')
plt.ylabel('cumulative percentage')
# Out:
# Text(0, 0.5, 'cumulative percentage')

# %%
def stackgraph(col):
    satisfied = train['satisfaction'] == 'satisfied'
    notsatisfied_neutral = train['satisfaction'] == 'neutral or dissatisfied'
    cat0 = train[col] [satisfied].dropna()
    cat1 = train[col] [notsatisfied_neutral].dropna()
    freq1 = cat0.value_counts()
    freq2 = cat1.value_counts()
    plotdata = pd.DataFrame({'satisfied':freq1 , 'neutral or dissatisfied':freq2 })
    plotdata2 = plotdata.div(plotdata.sum(axis=1),axis=0)*100
    plotdata2.plot(kind='bar',stacked =True)
    plt.legend(train['satisfaction'].unique(),bbox_to_anchor = (1.05,1))
    plt.xlabel(f'{col}')
    plt.ylabel('cumulative percentage')

# %%
stackgraph('type_of_travel')

# %%
categorical_features
# Out:
# ['Gender',
#  'customer_type',
#  'type_of_travel',
#  'customer_class',
#  'inflight_wifi_service',
#  'departure_arrival_time_convenient',
#  'ease_of_online_booking',
#  'gate_location',
#  'food_and_drink',
#  'online_boarding',
#  'seat_comfort',
#  'inflight_entertainment',
#  'onboard_service',
#  'leg_room_service',
#  'baggage_handling',
#  'checkin_service',
#  'inflight_service',
#  'cleanliness',
#  'satisfaction']

# %%
stackgraph('customer_class')

# %%
stackgraph('inflight_wifi_service')

# %%
stackgraph('departure_arrival_time_convenient')

# %%
stackgraph('gate_location')

# %%
stackgraph('food_and_drink')

# %%
stackgraph('online_boarding')

# %%
stackgraph('seat_comfort')

# %%
stackgraph('inflight_entertainment')

# %%
stackgraph('onboard_service')

# %%
stackgraph('leg_room_service')

# %%
stackgraph('baggage_handling')

# %%
stackgraph('checkin_service')

# %%
stackgraph('Gender')

# %%
stackgraph('cleanliness')

# %%
stackgraph('inflight_service')

# %%
stackgraph('inflight_wifi_service')
